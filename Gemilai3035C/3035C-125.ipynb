# %% [markdown]
# <a href="https://colab.research.google.com/github/cafetalk/coffee_machine_evaluating/blob/main/Gemilai3035C/3035C-128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
import numpy as np

# A list of colors for the 10 lines
colors = [
    '#E67E22', '#2ECC71', '#3498DB', '#9B59B6', '#F1C40F',
    '#E74C3C', '#1ABC9C', '#34495E', '#A93226', '#1F618D'
]

# Extracted data from the 30 provided images (1-30)
# The order is: left-to-right, then top-to-bottom for each image.
data_s1 = [90.3, 88.8, 89.8, 89.8, 90.3, 90.9, 89.8, 91.5, 91.8, 89.2]
data_s2 = [90.4, 88.9, 90.0, 89.6, 90.0, 91.2, 90.2, 91.7, 92.3, 89.1]
data_s3 = [90.3, 88.6, 90.1, 89.8, 90.6, 91.6, 89.8, 91.6, 92.1, 89.2]
data_s4 = [90.5, 88.9, 90.3, 89.9, 90.8, 91.7, 89.9, 91.5, 91.9, 89.2]
data_s5 = [90.6, 90.8, 90.9, 90.9, 91.2, 91.8, 90.8, 92.3, 92.7, 89.7]
data_s6 = [90.5, 89.5, 90.5, 90.4, 90.4, 91.3, 90.6, 91.6, 92.3, 89.9]
data_s7 = [90.6, 89.9, 90.5, 89.6, 90.7, 91.8, 90.5, 92.2, 92.1, 90.2]
data_s8 = [90.5, 90.5, 90.7, 89.8, 90.6, 91.7, 90.9, 92.2, 92.5, 89.9]
data_s9 = [90.5, 90.5, 90.5, 89.9, 90.9, 91.7, 91.3, 92.4, 92.6, 90.5]
data_s10 = [90.4, 90.6, 90.4, 90.2, 91.1, 91.8, 91.3, 92.5, 93.1, 91.3]
data_s11 = [90.4, 90.3, 90.5, 90.1, 91.8, 92.0, 91.3, 92.7, 93.1, 91.7]
data_s12 = [90.4, 90.9, 90.9, 90.5, 92.0, 92.3, 91.4, 92.9, 93.4, 92.4]
data_s13 = [90.3, 91.0, 90.7, 90.7, 92.0, 92.2, 91.2, 92.9, 93.3, 92.5]
data_s14 = [90.4, 91.2, 90.7, 91.0, 92.5, 92.4, 91.7, 92.9, 93.4, 92.6]
data_s15 = [90.3, 91.1, 90.9, 91.0, 92.3, 92.2, 91.8, 93.1, 93.4, 93.0]
data_s16 = [90.4, 91.2, 91.0, 91.1, 92.5, 92.3, 91.7, 92.9, 93.6, 93.3]
data_s17 = [90.4, 91.1, 90.8, 91.5, 92.2, 92.3, 91.9, 93.1, 93.7, 93.2]
data_s18 = [90.3, 91.1, 90.9, 91.4, 92.6, 92.2, 91.9, 93.2, 93.7, 93.6]
data_s19 = [90.3, 91.1, 91.0, 91.5, 92.9, 92.0, 92.2, 93.0, 93.7, 93.4]
data_s20 = [90.2, 91.1, 90.9, 91.5, 92.7, 92.1, 92.2, 93.2, 93.7, 93.4]
data_s21 = [90.1, 90.8, 90.9, 91.5, 92.8, 91.9, 92.1, 93.1, 93.8, 93.7]
data_s22 = [90.0, 90.9, 91.0, 91.6, 92.8, 91.9, 92.3, 93.1, 93.5, 93.7]
data_s23 = [89.8, 90.6, 90.9, 91.5, 92.9, 91.9, 92.1, 93.2, 93.7, 93.8]
data_s24 = [89.6, 90.8, 90.9, 91.5, 92.8, 91.8, 92.4, 93.2, 93.7, 93.7]
data_s25 = [89.5, 90.8, 90.9, 91.6, 92.9, 91.7, 92.3, 93.3, 93.9, 93.7]
data_s26 = [89.4, 90.7, 90.8, 91.7, 92.9, 91.6, 92.5, 93.2, 93.6, 93.7]
data_s27 = [89.2, 90.7, 90.7, 91.6, 92.9, 91.4, 92.5, 93.2, 93.7, 93.8]
data_s28 = [89.2, 90.6, 90.8, 91.7, 93.1, 91.3, 92.5, 93.1, 93.5, 93.7]
data_s29 = [89.0, 90.6, 90.8, 91.8, 93.1, 91.1, 92.3, 93.2, 93.7, 93.8]
data_s30 = [88.9, 90.5, 90.7, 91.5, 93.1, 91.1, 92.5, 93.2, 93.6, 93.7]

# Combine all data into a single list of lists
all_data = [
    data_s1, data_s2, data_s3, data_s4, data_s5, data_s6, data_s7, data_s8, data_s9, data_s10,
    data_s11, data_s12, data_s13, data_s14, data_s15, data_s16, data_s17, data_s18, data_s19, data_s20,
    data_s21, data_s22, data_s23, data_s24, data_s25, data_s26, data_s27, data_s28, data_s29, data_s30
]

# Organize the data into 10 arrays as requested
final_arrays = [[] for _ in range(10)]
for frame_data in all_data:
    for i in range(10):
        if len(frame_data) > i:
            final_arrays[i].append(frame_data[i])

# Create the plot
# Set the background to black
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14, 8))
# Set the title and label colors to white
ax.set_title('Gemilai 3035C Temperature Curve Plotting(125° Pre:2s,2s)', fontsize=18, pad=20, color='white')
ax.set_xlabel('Time (seconds)', fontsize=12, color='white')
ax.set_ylabel('Temperature °', fontsize=12, color='white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.set_ylim(85, 98)
ax.set_yticks(np.arange(85, 98, 1))

# Add horizontal grid lines for more detailed y-axis reference
ax.grid(axis='y', linestyle='--', alpha=0.2, color='white')

# Plot the 10 data curves with different colors and labels
for i in range(10):
    ax.plot(range(1, 31), final_arrays[i], label=f'Round {i}', color=colors[i], marker='o', markersize=4, linewidth=2)

# Plot the reference line, making it white and more prominent
ax.axhline(y=92, color='white', linestyle='--', linewidth=2, label='Reference Line (92)')

# Add a legend to explain the colors
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1.0))

# Add the watermark in the four quadrants
fig_size_inches = fig.get_size_inches()
x_center = fig_size_inches[0] / 2.0
y_center = fig_size_inches[1] / 2.0
ax.text(x_center / fig_size_inches[0] / 2, y_center / fig_size_inches[1] / 2, 'cafetalk',
        transform=ax.transAxes, fontsize=40, color='white', alpha=0.2, ha='center', va='center', rotation=45)
ax.text(x_center / fig_size_inches[0] * 1.5, y_center / fig_size_inches[1] / 2, 'cafetalk',
        transform=ax.transAxes, fontsize=40, color='white', alpha=0.2, ha='center', va='center', rotation=45)
ax.text(x_center / fig_size_inches[0] / 2, y_center / fig_size_inches[1] * 1.5, 'cafetalk',
        transform=ax.transAxes, fontsize=40, color='white', alpha=0.2, ha='center', va='center', rotation=45)
ax.text(x_center / fig_size_inches[0] * 1.5, y_center / fig_size_inches[1] * 1.5, 'cafetalk',
        transform=ax.transAxes, fontsize=40, color='white', alpha=0.2, ha='center', va='center', rotation=45)

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.9, 1])

# Save the plot to a file
plt.savefig('temperature_plot.png', dpi=300)

print("Plot has been successfully generated and saved as temperature_plot.png")
# Out:
# Plot has been successfully generated and saved as temperature_plot.png

# %% [markdown]
# # 新段落
